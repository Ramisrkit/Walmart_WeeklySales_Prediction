# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramisrkit/Walmart_WeeklySales_Prediction/blob/main/Walmart_WeeklySales_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Walmart_Store_sales.csv')

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df.drop(['Holiday_Flag','Temperature'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#              Store  Weekly_Sales   Fuel_Price          CPI  Unemployment
# count  6435.000000  6.435000e+03  6435.000000  6435.000000   6435.000000
# mean     23.000000  1.046965e+06     3.358607   171.578394      7.999151
# std      12.988182  5.643666e+05     0.459020    39.356712      1.875885
# min       1.000000  2.099862e+05     2.472000   126.064000      3.879000
# 25%      12.000000  5.533501e+05     2.933000   131.735000      6.891000
# 50%      23.000000  9.607460e+05     3.445000   182.616521      7.874000
# 75%      34.000000  1.420159e+06     3.735000   212.743293      8.622000
# max      45.000000  3.818686e+06     4.468000   227.232807     14.313000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Fuel_Price    6435 non-null   float64
#  4   CPI           6435 non-null   float64
#  5   Unemployment  6435 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 301.8+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Fuel_Price    6435 non-null   float64
#  4   CPI           6435 non-null   float64
#  5   Unemployment  6435 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 301.8+ KB

# %%
df['Date']=pd.to_datetime(df['Date'], format='%d-%m-%Y', errors='coerce')

# %%
df
# Out:
#       Store       Date  Weekly_Sales  Fuel_Price         CPI  Unemployment
# 0         1 2010-02-05    1643690.90       2.572  211.096358         8.106
# 1         1 2010-02-12    1641957.44       2.548  211.242170         8.106
# 2         1 2010-02-19    1611968.17       2.514  211.289143         8.106
# 3         1 2010-02-26    1409727.59       2.561  211.319643         8.106
# 4         1 2010-03-05    1554806.68       2.625  211.350143         8.106
# ...     ...        ...           ...         ...         ...           ...
# 6430     45 2012-09-28     713173.95       3.997  192.013558         8.684
# 6431     45 2012-10-05     733455.07       3.985  192.170412         8.667
# 6432     45 2012-10-12     734464.36       4.000  192.327265         8.667
# 6433     45 2012-10-19     718125.53       3.969  192.330854         8.667
# 6434     45 2012-10-26     760281.43       3.882  192.308899         8.667
#
# [6435 rows x 6 columns]

# %%
df['Year']=df['Date'].dt.year
df['Month']=df['Date'].dt.month
df['Day']=df['Date'].dt.day

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df
# Out:
#       Store  Weekly_Sales  Fuel_Price         CPI  Unemployment  Year  Month  \
# 0         1    1643690.90       2.572  211.096358         8.106  2010      2
# 1         1    1641957.44       2.548  211.242170         8.106  2010      2
# 2         1    1611968.17       2.514  211.289143         8.106  2010      2
# 3         1    1409727.59       2.561  211.319643         8.106  2010      2
# 4         1    1554806.68       2.625  211.350143         8.106  2010      3
# ...     ...           ...         ...         ...           ...   ...    ...
# 6430     45     713173.95       3.997  192.013558         8.684  2012      9
# 6431     45     733455.07       3.985  192.170412         8.667  2012     10
# 6432     45     734464.36       4.000  192.327265         8.667  2012     10
# 6433     45     718125.53       3.969  192.330854         8.667  2012     10
# 6434     45     760281.43       3.882  192.308899         8.667  2012     10
#
#       Day
# 0       5
# 1      12
# ...

# %%
number=df.select_dtypes(include=['int64','float64']).columns

# %%
df.isnull().sum()
# Out:
# Store           0
# Weekly_Sales    0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# Year            0
# Month           0
# Day             0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    6435
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for i in number:
  sns.boxplot(df[i])
  plt.show()

# %%
for i in number:
  q1=df[i].quantile(0.25)
  q3=df[i].quantile(0.75)
  iqr=q3-q1
  low=q1-1.5*iqr
  high=q3+1.5*iqr
  df[i]=df[i].clip(high,low)

# %%
for i in number:
  sns.boxplot(df[i])
  plt.show()

# %%
df.isnull().sum()
# Out:
# Store           0
# Weekly_Sales    0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# Year            0
# Month           0
# Day             0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    6435
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop(['Weekly_Sales'],axis=1),df['Weekly_Sales'],train_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
st=StandardScaler()
x_train=st.fit_transform(x_train)
x_test=st.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(y_pred,y_test)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
dt=RandomForestRegressor(max_depth=15,n_estimators=300,min_samples_split=5,min_samples_leaf=2,max_samples=0.45,bootstrap=True)

# %%
dt.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=15, max_samples=0.45, min_samples_leaf=2,
#                       min_samples_split=5, n_estimators=300)

# %%
y_predict=dt.predict(x_test)

# %%
dt.score(x_train,y_train)
# Out:
# 0.9678223300819829

# %%
dt.score(x_test,y_test)
# Out:
# 0.9335725535528846

# %%
parameters= {
    'n_estimators': [200,300],
    'max_depth': [10, 15, 20],
    'min_samples_split': [5, 10, 15],
    'min_samples_leaf': [2, 3, 5],
    'max_samples':[0.25,0.40,0.45],
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid=GridSearchCV(estimator=dt,cv=3,param_grid=parameters,n_jobs=-1,verbose=1)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# GridSearchCV(cv=3,
#              estimator=RandomForestRegressor(max_depth=15, max_samples=0.45,
#                                              min_samples_leaf=2,
#                                              min_samples_split=5,
#                                              n_estimators=300),
#              n_jobs=-1,
#              param_grid={'max_depth': [10, 15, 20],
#                          'max_samples': [0.25, 0.4, 0.45],
#                          'min_samples_leaf': [2, 3, 5],
#                          'min_samples_split': [5, 10, 15],
#                          'n_estimators': [200, 300]},
#              verbose=1)

# %%
grid.best_params_
# Out:
# {'max_depth': 20,
#  'max_samples': 0.45,
#  'min_samples_leaf': 2,
#  'min_samples_split': 5,
#  'n_estimators': 200}

# %%
grid.score(x_train,y_train)
# Out:
# 0.9684855352665015

# %%
grid.score(x_test,y_test)
# Out:
# 0.9337571387735715

# %%
from sklearn.decomposition import PCA
g=PCA(n_components=2)
h=g.fit_transform(x_train)

# %%
h.shape
# Out:
# (1287, 2)

# %%
y_train.shape
# Out:
# (1287,)

# %%
df.columns
# Out:
# Index(['Store', 'Weekly_Sales', 'Fuel_Price', 'CPI', 'Unemployment', 'Year',
#        'Month', 'Day'],
#       dtype='object')

# %%
plt.scatter(y_predict,y_test)

# %%
from sklearn import r2
